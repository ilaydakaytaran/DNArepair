# %% [markdown]
# ## 1) Obtain genes

# %%
# execute this cell to authorize the notebook
from google.colab import drive
drive.mount("./drive", force_remount=True)
# Out:
# Mounted at ./drive

# %%
# execute this cell to bind the file in drive to the code
from os.path import join
import pandas as pd
import numpy as np

path_prefix = "./drive/My Drive/PURE-DNA_damage_repair/"

# %%
# getting df of list of all genes

fname_in_ner = "maf_analysis_all_repair/ncbi_all_gene_result_27122023.txt"

with open(join(path_prefix, fname_in_ner), "r") as f_in:
  df_in = pd.read_csv(f_in, delimiter='\t')           # our list of genes

df_all = df_in.dropna(axis="columns", how="all")       # keeping only filled columns
df_all = df_all.dropna(axis="rows", how="all")

df_all
# Out:
#        tax_id      Org_name     GeneID  CurrentID Status        Symbol  \
# 0        9606  Homo sapiens       7157          0   live          TP53
# 1        9606  Homo sapiens       1956          0   live          EGFR
# 2        9606  Homo sapiens        348          0   live          APOE
# 3        9606  Homo sapiens       7124          0   live           TNF
# 4        9606  Homo sapiens       7422          0   live         VEGFA
# ...       ...           ...        ...        ...    ...           ...
# 20622    9606  Homo sapiens  100996709          0   live  LOC100996709
# 20623    9606  Homo sapiens  100996701          0   live  LOC100996701
# 20624    9606  Homo sapiens  100996696          0   live  LOC100996696
# 20625    9606  Homo sapiens  100507221          0   live  LOC100507221
# 20626    9606  Homo sapiens  100129098          0   live  LOC100129098
#
#                                             Aliases  \
# 0                     BCC7, BMFS5, LFS1, P53, TRP53
# 1      ERBB, ERBB1, ERRP, HER1, NISBD2, PIG61, mENA
# 2                    AD2, APO-E, ApoE4, LDLCQ5, LPG
# 3              DIF-alpha, TNFA, TNFSF2, TNLG1F, TNF
# 4                          L-VEGF, MVCD1, VEGF, VPF
# ...                                             ...
# 20622                                           NaN
# 20623                                           NaN
# 20624                                           NaN
# 20625                                           NaN
# 20626                                           NaN
#
#                                    description  \
# 0                            tumor protein p53
# 1             epidermal growth factor receptor
# 2                             apolipoprotein E
# 3                        tumor necrosis factor
# 4         vascular endothelial growth factor A
# ...                                        ...
# 20622  ADP-ribosylation factor-like protein 17
# 20623             uncharacterized LOC100996701
# 20624     polyadenylate-binding protein 4-like
# 20625             uncharacterized LOC100507221
# 20626             uncharacterized LOC100129098
#
#                                       other_designations map_location  \
# 0      cellular tumor antigen p53|antigen NY-CO-13|mu...      17p13.1
# 1      epidermal growth factor receptor|EGFR vIII|avi...       7p11.2
# 2                     apolipoprotein E|apolipoprotein E3     19q13.32
# 3      tumor necrosis factor|APC1 protein|TNF, macrop...      6p21.33
# 4      vascular endothelial growth factor A, long for...       6p21.1
# ...                                                  ...          ...
# 20622            ADP-ribosylation factor-like protein 17          NaN
# 20623               uncharacterized protein LOC100996701     12q24.33
# 20624               polyadenylate-binding protein 4-like      12q14.1
# 20625               uncharacterized protein LOC100507221      16p11.2
# 20626                 translation initiation factor IF-2      8q11.23
#
#       chromosome genomic_nucleotide_accession.version  \
# 0             17                         NC_000017.11
# 1              7                         NC_000007.14
# 2             19                         NC_000019.10
# 3              6                         NC_000006.12
# 4              6                         NC_000006.12
# ...          ...                                  ...
# 20622         17                                  NaN
# 20623         12                         NC_000012.12
# 20624         12                         NC_000012.12
# 20625         16                         NC_000016.10
# 20626          8                         NC_000008.11
#
#        start_position_on_the_genomic_accession  \
# 0                                    7668421.0
# 1                                   55019017.0
# 2                                   44905796.0
# 3                                   31575565.0
# 4                                   43770211.0
# ...                                        ...
# 20622                                      NaN
# 20623                              131663774.0
# 20624                               59812094.0
# 20625                               32264029.0
# 20626                               54465594.0
#
#        end_position_on_the_genomic_accession orientation  exon_count    OMIM
# 0                                  7687490.0       minus        13.0  191170
# 1                                 55211628.0        plus        32.0  131550
# 2                                 44909393.0        plus         6.0  107741
# 3                                 31578336.0        plus         4.0  191160
# 4                                 43786487.0        plus         9.0  192240
# ...                                      ...         ...         ...     ...
# 20622                                    NaN         NaN         NaN     NaN
# 20623                            131664548.0       minus         1.0     NaN
# 20624                             59812618.0        plus         1.0     NaN
# 20625                             32280475.0       minus         5.0     NaN
# 20626                             54470426.0       minus         2.0     NaN
#
# [20627 rows x 17 columns]

# %% [markdown]
# ## 2) NCBI Data Acquisition

# %% [markdown]
# #### a) Install NCBI API

# %%
# use a virtual environment
# !apt install python3.10-venv
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.10-venv is already the newest version (3.10.12-1~22.04.3).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
# create the virtual environment using the name .venv_datasets
# !python -m venv .venv_datasets
# !source .venv_datasets/bin/activate

# %%
# install wheel
# !pip install wheel
# Out:
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (0.43.0)

# %%
# install the latest available datasets package
# !pip install --upgrade ncbi-datasets-pylib
# Out:
# Requirement already satisfied: ncbi-datasets-pylib in /usr/local/lib/python3.10/dist-packages (16.6.0)
# Requirement already satisfied: argcomplete==3.0.8 in /usr/local/lib/python3.10/dist-packages (from ncbi-datasets-pylib) (3.0.8)
# Requirement already satisfied: argh==0.28.1 in /usr/local/lib/python3.10/dist-packages (from ncbi-datasets-pylib) (0.28.1)
# Requirement already satisfied: attrs==23.1.0 in /usr/local/lib/python3.10/dist-packages (from ncbi-datasets-pylib) (23.1.0)
# Requirement already satisfied: gffutils==0.11.1 in /usr/local/lib/python3.10/dist-packages (from ncbi-datasets-pylib) (0.11.1)
# Requirement already satisfied: jinja2==3.1.2 in /usr/local/lib/python3.10/dist-packages (from ncbi-datasets-pylib) (3.1.2)
# Requirement already satisfied: jsonlines==3.1.0 in /usr/local/lib/python3.10/dist-packages (from ncbi-datasets-pylib) (3.1.0)
# Requirement already satisfied: markupsafe==2.1.2 in /usr/local/lib/python3.10/dist-packages (from ncbi-datasets-pylib) (2.1.2)
# Requirement already satisfied: protobuf==4.23.0 in /usr/local/lib/python3.10/dist-packages (from ncbi-datasets-pylib) (4.23.0)
# Requirement already satisfied: pyfaidx==0.7.2.1 in /usr/local/lib/python3.10/dist-packages (from ncbi-datasets-pylib) (0.7.2.1)
# Requirement already satisfied: python-dateutil==2.8.2 in /usr/local/lib/python3.10/dist-packages (from ncbi-datasets-pylib) (2.8.2)
# Requirement already satisfied: simplejson==3.19.1 in /usr/local/lib/python3.10/dist-packages (from ncbi-datasets-pylib) (3.19.1)
# Requirement already satisfied: six==1.16.0 in /usr/local/lib/python3.10/dist-packages (from ncbi-datasets-pylib) (1.16.0)
# Requirement already satisfied: urllib3==1.26.15 in /usr/local/lib/python3.10/dist-packages (from ncbi-datasets-pylib) (1.26.15)
# Requirement already satisfied: setuptools==67.7.2 in /usr/local/lib/python3.10/dist-packages (from ncbi-datasets-pylib) (67.7.2)

# %%
# verify installation
# !python -c 'import ncbi.datasets.openapi; print(ncbi.datasets.openapi.__version__)'
# Out:
# 16.6.0

# %% [markdown]
# #### b) Get SwissProt ID of each gene

# %%
from typing import List

from ncbi.datasets.openapi import ApiClient as DatasetsApiClient
from ncbi.datasets.openapi import ApiException as DatasetsApiException
from ncbi.datasets import GeneApi as DatasetsGeneApi
from ncbi.datasets.openapi.models import V1GeneMatch

# %%
def return_swissprot_information(gene_record: V1GeneMatch):
  # print any errors that occured while executing the above query, e.g. invalid identifier
  if gene_record.warnings:
    with open(join(path_prefix, "maf_analysis_all_repair/warnings.txt"), "a+") as f:
      f.write(str(gene_record.warnings))
      f.write("\n\n")
      return "NotFound"
  if gene_record.errors:
    with open(join(path_prefix, "maf_analysis_all_repair/errors.txt"), "a+") as f:
      f.write(str(gene_record.errors))
      f.write("\n\n")
      return "NotFound"

  # print gene metadata fields
  if gene_record.gene:
    gene_dictionary = gene_record.gene.to_dict()
    if "swiss_prot_accessions" not in gene_dictionary.keys():
      with open(join(path_prefix, "maf_analysis_all_repair/genes_without_swissprot_id_found.txt"), "a+") as f:
        f.write(str(gene_dictionary))
        f.write("\n\n")
      return "NotFound"
    else:
      return gene_dictionary['swiss_prot_accessions']

# %%
# get transcripts for all repair genes

# provide gene ids as a list of integers
gene_ids = list(df_all['GeneID'])

# create small chunks for api to work
chunk_size = 100
chunks = [gene_ids[i:i + chunk_size] for i in range(0, len(gene_ids), chunk_size)]

for chunk in chunks:
  with DatasetsApiClient() as api_client:
    gene_api = DatasetsGeneApi(api_client)

    try:
      # retrieve gene metadata for the list of gene ids
      gene_reply = gene_api.gene_metadata_by_id(chunk)
      for gene in gene_reply.genes:
        # get swissprot id list
        swissprot = return_swissprot_information(gene)
        # write into df_all
        if swissprot == "NotFound":
          df_all.loc[df_all['GeneID'] == int(gene.query[0]), 'swissprot_id'] = swissprot
        else:
          all_ids = str(swissprot[0])
          for id in swissprot[1:]:
            all_ids += ", " + str(id)
          df_all.loc[df_all['GeneID'] == int(gene.query[0]), 'swissprot_id'] = all_ids

    except DatasetsApiException as e:
      print(f"Exception when calling GeneApi: {e}\n")

df_all
# Out:
#        tax_id      Org_name     GeneID  CurrentID Status        Symbol  \
# 0        9606  Homo sapiens       7157          0   live          TP53
# 1        9606  Homo sapiens       1956          0   live          EGFR
# 2        9606  Homo sapiens        348          0   live          APOE
# 3        9606  Homo sapiens       7124          0   live           TNF
# 4        9606  Homo sapiens       7422          0   live         VEGFA
# ...       ...           ...        ...        ...    ...           ...
# 20622    9606  Homo sapiens  100996709          0   live  LOC100996709
# 20623    9606  Homo sapiens  100996701          0   live  LOC100996701
# 20624    9606  Homo sapiens  100996696          0   live  LOC100996696
# 20625    9606  Homo sapiens  100507221          0   live  LOC100507221
# 20626    9606  Homo sapiens  100129098          0   live  LOC100129098
#
#                                             Aliases  \
# 0                     BCC7, BMFS5, LFS1, P53, TRP53
# 1      ERBB, ERBB1, ERRP, HER1, NISBD2, PIG61, mENA
# 2                    AD2, APO-E, ApoE4, LDLCQ5, LPG
# 3              DIF-alpha, TNFA, TNFSF2, TNLG1F, TNF
# 4                          L-VEGF, MVCD1, VEGF, VPF
# ...                                             ...
# 20622                                           NaN
# 20623                                           NaN
# 20624                                           NaN
# 20625                                           NaN
# 20626                                           NaN
#
#                                    description  \
# 0                            tumor protein p53
# 1             epidermal growth factor receptor
# 2                             apolipoprotein E
# 3                        tumor necrosis factor
# 4         vascular endothelial growth factor A
# ...                                        ...
# 20622  ADP-ribosylation factor-like protein 17
# 20623             uncharacterized LOC100996701
# 20624     polyadenylate-binding protein 4-like
# 20625             uncharacterized LOC100507221
# 20626             uncharacterized LOC100129098
#
#                                       other_designations map_location  \
# 0      cellular tumor antigen p53|antigen NY-CO-13|mu...      17p13.1
# 1      epidermal growth factor receptor|EGFR vIII|avi...       7p11.2
# 2                     apolipoprotein E|apolipoprotein E3     19q13.32
# 3      tumor necrosis factor|APC1 protein|TNF, macrop...      6p21.33
# 4      vascular endothelial growth factor A, long for...       6p21.1
# ...                                                  ...          ...
# 20622            ADP-ribosylation factor-like protein 17          NaN
# 20623               uncharacterized protein LOC100996701     12q24.33
# 20624               polyadenylate-binding protein 4-like      12q14.1
# 20625               uncharacterized protein LOC100507221      16p11.2
# 20626                 translation initiation factor IF-2      8q11.23
#
#       chromosome genomic_nucleotide_accession.version  \
# 0             17                         NC_000017.11
# 1              7                         NC_000007.14
# 2             19                         NC_000019.10
# 3              6                         NC_000006.12
# 4              6                         NC_000006.12
# ...          ...                                  ...
# 20622         17                                  NaN
# 20623         12                         NC_000012.12
# 20624         12                         NC_000012.12
# 20625         16                         NC_000016.10
# 20626          8                         NC_000008.11
#
#        start_position_on_the_genomic_accession  \
# 0                                    7668421.0
# 1                                   55019017.0
# 2                                   44905796.0
# 3                                   31575565.0
# 4                                   43770211.0
# ...                                        ...
# 20622                                      NaN
# 20623                              131663774.0
# 20624                               59812094.0
# 20625                               32264029.0
# 20626                               54465594.0
#
#        end_position_on_the_genomic_accession orientation  exon_count    OMIM  \
# 0                                  7687490.0       minus        13.0  191170
# 1                                 55211628.0        plus        32.0  131550
# 2                                 44909393.0        plus         6.0  107741
# 3                                 31578336.0        plus         4.0  191160
# 4                                 43786487.0        plus         9.0  192240
# ...                                      ...         ...         ...     ...
# 20622                                    NaN         NaN         NaN     NaN
# 20623                            131664548.0       minus         1.0     NaN
# 20624                             59812618.0        plus         1.0     NaN
# 20625                             32280475.0       minus         5.0     NaN
# 20626                             54470426.0       minus         2.0     NaN
#
#       swissprot_id
# 0           P04637
# 1           P00533
# 2           P02649
# 3           P01375
# 4           P15692
# ...            ...
# 20622     NotFound
# 20623     NotFound
# 20624     NotFound
# 20625     NotFound
# 20626     NotFound
#
# [20627 rows x 18 columns]

# %%
# save into a file
df_all.to_csv(join(path_prefix, "maf_analysis_all_repair/df_all_w_most_swissprot_ids.txt"), sep="\t")

# %% [markdown]
# #### c) Find the canonical swissprot ID for those with multiple IDs (manual check)

# %%
print(df_all[df_all["swissprot_id"].str.contains(", ")].shape)
df_all[df_all["swissprot_id"].str.contains(", ")]
# Out:
# (55, 18)
#        tax_id      Org_name     GeneID  CurrentID Status          Symbol  \
# 32       9606  Homo sapiens       1029          0   live          CDKN2A
# 134      9606  Homo sapiens       5621          0   live            PRNP
# 292      9606  Homo sapiens       2778          0   live            GNAS
# 302      9606  Homo sapiens        796          0   live           CALCA
# 967      9606  Homo sapiens       1649          0   live           DDIT3
# 1199     9606  Homo sapiens       2074          0   live           ERCC6
# 1217     9606  Homo sapiens       5170          0   live           PDPK1
# 1318     9606  Homo sapiens      27113          0   live            BBC3
# 1705     9606  Homo sapiens       6241          0   live            RRM2
# 1757     9606  Homo sapiens       9378          0   live           NRXN1
# 2179     9606  Homo sapiens       6957          0   live             TRB
# 2206     9606  Homo sapiens      23513          0   live           SCRIB
# 2372     9606  Homo sapiens       1523          0   live            CUX1
# 2440     9606  Homo sapiens       5583          0   live           PRKCH
# 2655     9606  Homo sapiens       7112          0   live            TMPO
# 2758     9606  Homo sapiens       6955          0   live             TRA
# 2820     9606  Homo sapiens       7957          0   live           EPM2A
# 2985     9606  Homo sapiens       8241          0   live           RBM10
# 4129     9606  Homo sapiens      23499          0   live           MACF1
# 4221     9606  Homo sapiens       4666          0   live            NACA
# 4511     9606  Homo sapiens      27433          0   live           TOR2A
# 5483     9606  Homo sapiens       9369          0   live           NRXN3
# 5552     9606  Homo sapiens     399687          0   live          MYO18A
# 6851     9606  Homo sapiens      22891          0   live          ZNF365
# 7095     9606  Homo sapiens      81488          0   live          POLR2M
# 7562     9606  Homo sapiens      51082          0   live          POLR1D
# 8137     9606  Homo sapiens     163590          0   live        TOR1AIP2
# 8609     9606  Homo sapiens       9379          0   live           NRXN2
# 8949     9606  Homo sapiens      51182          0   live          HSPA14
# 9023     9606  Homo sapiens       4338          0   live           MOCS2
# 10469    9606  Homo sapiens      23420          0   live           NOMO1
# 10745    9606  Homo sapiens       9465          0   live           AKAP7
# 11534    9606  Homo sapiens      10326          0   live          SIRPB1
# 11661    9606  Homo sapiens     445329          0   live         SULT1A4
# 11985    9606  Homo sapiens       9910          0   live        RABGAP1L
# 12355    9606  Homo sapiens     114112          0   live          TXNRD3
# 13174    9606  Homo sapiens      23008          0   live         KLHDC10
# 13722    9606  Homo sapiens      22997          0   live          IGSF9B
# 14018    9606  Homo sapiens       5342          0   live          PLGLB2
# 14176    9606  Homo sapiens  101060684          0   live          NBPF26
# 14640    9606  Homo sapiens     115509          0   live          ZNF689
# 14706    9606  Homo sapiens      23015          0   live         GOLGA8A
# 15013    9606  Homo sapiens  100528062          0   live  ARMCX5-GPRASP2
# 15411    9606  Homo sapiens      83849          0   live           SYT15
# 15534    9606  Homo sapiens     113829          0   live         SLC35A4
# 16778    9606  Homo sapiens     284293          0   live            HMSD
# 16845    9606  Homo sapiens     729447          0   live          GAGE2A
# 16846    9606  Homo sapiens     729438          0   live         CASTOR2
# 16982    9606  Homo sapiens     340527          0   live           NHSL2
# 17760    9606  Homo sapiens      57501          0   live          CFAP92
# 18165    9606  Homo sapiens     653598          0   live         PPIAL4C
# 19160    9606  Homo sapiens  122394733          0   live         TMSB15C
# 19219    9606  Homo sapiens     147660          0   live          ZNF578
# 19297    9606  Homo sapiens  112488736          0   live         TAF11L7
# 19523    9606  Homo sapiens  100129515          0   live            ETDB
#
#                                                  Aliases  \
# 32     ARF, CAI2, CDK4I, CDKN2, CMM2, INK4, INK4A, ML...
# 134    ASCR, AltPrP, CD230, CJD, GSS, KURU, PRIP, PrP...
# 292    AHO, C20orf451, GPSA, GSA, GSP, NESP, PITA3, P...
# 302    CALC1, CGRP, CGRP-I, CGRP-alpha, CGRP1, CT, KC...
# 967    AltDDIT3, C/EBPzeta, CEBPZ, CHOP, CHOP-10, CHO...
# 1199   ARMD5, CKN2, COFS, COFS1, CSB, CSB-PGBD3, POF1...
# 1217                        PDK1, PDPK2, PDPK2P, PRO0461
# 1318                                   JFY-1, JFY1, PUMA
# 1705                              C2orf48, R2, RR2, RR2M
# 1757                            Hs.22998, PTHSL2, SCZD17
# 2179                                          TCRB@, TRB
# 2206                CRIB1, SCRB11, Vartul, oSCRIB, SCRIB
# 2372   CASP, CDP, CDP/Cut, CDP1, COY1, CUTL1, CUX, Cl...
# 2440                 PKC-L, PKCL, PRKCL, nPKC-eta, uORF2
# 2655                     CMD1T, LAP2, LEMD4, PRO0868, TP
# 2758                                    IMD7, TCRA@, TRA
# 2820                                          EPM2, MELF
# 2985   DXS8237E, GPATC9, GPATCH9, MINAS-60, S1-1, TAR...
# 4129   ABP620, ACF7, KIAA0754, LIS9, Lnc-PMIF, MACF, ...
# 4221                      HSD48, NAC-alpha1, skNAC, NACA
# 4511                                               TORP1
# 5483                                            C14orf60
# 5552                MAJN, MYSPDZ, SP-R210, SPR210, TIAF1
# 6851                                  Su48, UAND, ZNF365
# 7095                       GCOM1, GRINL1A, Gdown, Gdown1
# 7562   AC19, POLR1C, RPA16, RPA9, RPAC2, RPC16, RPO1-...
# 8137                                 IFRG15, LULL1, NET9
# 8609                                                 NaN
# 8949                           HSP70-4, HSP70L1, MSANTD7
# 9023                          MCBPE, MOCO1, MOCODB, MPTS
# 10469                                          Nomo, PM5
# 10745                                     AKAP15, AKAP18
# 11534                                CD172b, SIRP-BETA-1
# 11661  HAST3, M-PST, ST1A3, ST1A3/ST1A4, ST1A4, STM, ...
# 11985                                       HHL, TBC1D18
# 12355  TGR, TR2, TR2IT1, TRXR3, TXNR3IT1, TXNRD3NB, T...
# 13174                                     PNAS-138, slim
# 13722                               LINC00947, MIR4697HG
# 14018                  PLGLA, PLGLA1, PLGP1, PLGP2, PRGA
# 14176                                          NOTCH2NLR
# 14640                                             TIPUH1
# 14706                     CFAP286, FAP286, GM88, GOLGA8B
# 15013  ARMCX5-GPRASP2-BHLHB9-LINC00630, GPRASP3, bHLH...
# 15411                            CHR10SYTB, sytXV, SYT15
# 15534                                                NaN
# 16778                      ACC-6, ACC6, C18orf53, HSMD-v
# 16845                      CT4.2, GAGE-2, GAGE-2A, GAGE2
# 16846                                     GATSL1, GATSL2
# 16982                                                NaN
# 17760                                    FAP92, KIAA1257
# 18165                                             COAS-2
# 19160                                            TMSB15B
# 19219                                                NaN
# 19297                                            TAF11L5
# 19523                                    ETDA, LINC00633
#
#                                              description  \
# 32                  cyclin dependent kinase inhibitor 2A
# 134                    prion protein (Kanno blood group)
# 292                                   GNAS complex locus
# 302                 calcitonin related polypeptide alpha
# 967                    DNA damage inducible transcript 3
# 1199   ERCC excision repair 6, chromatin remodeling f...
# 1217       3-phosphoinositide dependent protein kinase 1
# 1318                            BCL2 binding component 3
# 1705      ribonucleotide reductase regulatory subunit M2
# 1757                                          neurexin 1
# 2179                          T cell receptor beta locus
# 2206               scribble planar cell polarity protein
# 2372                                 cut like homeobox 1
# 2440                                protein kinase C eta
# 2655                                        thymopoietin
# 2758                         T cell receptor alpha locus
# 2820                   EPM2A glucan phosphatase, laforin
# 2985                        RNA binding motif protein 10
# 4129             microtubule actin crosslinking factor 1
# 4221   nascent polypeptide associated complex subunit...
# 4511                            torsin family 2 member A
# 5483                                          neurexin 3
# 5552                                       myosin XVIIIA
# 6851                             zinc finger protein 365
# 7095                         RNA polymerase II subunit M
# 7562                  RNA polymerase I and III subunit D
# 8137                     torsin 1A interacting protein 2
# 8609                                          neurexin 2
# 8949       heat shock protein family A (Hsp70) member 14
# 9023                     molybdenum cofactor synthesis 2
# 10469                                  NODAL modulator 1
# 10745                       A-kinase anchoring protein 7
# 11534                   signal regulatory protein beta 1
# 11661                sulfotransferase family 1A member 4
# 11985               RAB GTPase activating protein 1 like
# 12355                            thioredoxin reductase 3
# 13174                         kelch domain containing 10
# 13722               immunoglobulin superfamily member 9B
# 14018                                plasminogen like B2
# 14176                                     NBPF member 26
# 14640                            zinc finger protein 689
# 14706                          golgin A8 family member A
# 15013                         ARMCX5-GPRASP2 readthrough
# 15411                                   synaptotagmin 15
# 15534                 solute carrier family 35 member A4
# 16778  histocompatibility minor serpin domain containing
# 16845                                       G antigen 2A
# 16846     cytosolic arginine sensor for mTORC1 subunit 2
# 16982                                         NHS like 2
# 17760  cilia and flagella associated protein 92 (puta...
# 18165                 peptidylprolyl isomerase A like 4C
# 19160                                  thymosin beta 15C
# 19219                            zinc finger protein 578
# 19297  TATA-box binding protein associated factor 11 ...
# 19523         embryonic testis differentiation homolog B
#
#                                       other_designations   map_location  \
# 32     cyclin-dependent kinase inhibitor 2A|CDK4 inhi...         9p21.3
# 134    major prion protein|alternative prion protein|...          20p13
# 292    protein ALEX|protein GNAS|protein SCG6 (secret...       20q13.32
# 302    calcitonin|calcitonin gene-related peptide 1|a...        11p15.2
# 967    DNA damage-inducible transcript 3 protein|C/EB...        12q13.3
# 1199   DNA excision repair protein ERCC-6|ERCC6-PGBD3...       10q11.23
# 1217   3-phosphoinositide-dependent protein kinase 1|...        16p13.3
# 1318   bcl-2-binding component 3|p53 up-regulated mod...       19q13.32
# 1705   ribonucleoside-diphosphate reductase subunit M...         2p25.1
# 1757                               neurexin-1|neurexin I         2p16.3
# 2179   M1-specific T cell receptor beta chain|T-cell ...           7q34
# 2206   protein scribble homolog|scribbled homolog|scr...         8q24.3
# 2372   protein CASP|Homeobox protein cut-like 1|CCAAT...         7q22.1
# 2440             protein kinase C eta type|Protein uPEP2        14q23.1
# 2655   thymopoietin|LEM domain containing 4|lamina-as...        12q23.1
# 2758   M1-specific T cell receptor alpha chain|T-cell...        14q11.2
# 2820   laforin|EPM2A, laforin glucan phosphatase|LAFP...         6q24.3
# 2985   RNA-binding protein 10|G-patch domain containi...         Xp11.3
# 4129   microtubule-actin cross-linking factor 1|620 k...         1p34.3
# 4221   nascent polypeptide-associated complex subunit...        12q13.3
# 4511   prosalusin|salusin-beta|torsin-2A|torsin-relat...        9q34.11
# 5483            neurexin 3|neurexin III|neurexin-3-alpha  14q24.3-q31.1
# 5552   unconventional myosin-XVIIIa|12 kDa TGF-beta-1...        17q11.2
# 6851   protein ZNF365|DISC1-binding zinc-finger prote...        10q21.2
# 7095   protein GRINL1A|GRINL1A downstream protein Gdo...        15q21.3
# 7562   DNA-directed RNA polymerases I and III subunit...        13q12.2
# 8137   torsin-1A-interacting protein 2|interferon alp...         1q25.2
# 8609                         neurexin-2-beta|neurexin II        11q13.1
# 8949   heat shock 70 kDa protein 14|HSP70-like protei...          10p13
# 9023   molybdopterin synthase catalytic subunit|molyb...         5q11.2
# 10469  nodal modulator 1|nodal modulator 3|pM5 protei...       16p13.11
# 10745  A-kinase anchoring protein 7|A kinase (PRKA) a...         6q23.2
# 11534  signal-regulatory protein beta-1|CD172 antigen...          20p13
# 11661  sulfotransferase 1A4|SLX1B-SULT1A4|Sulfotransf...        16p11.2
# 11985  rab GTPase-activating protein 1-like|TBC1 doma...         1q25.1
# 12355  thioredoxin reductase 3|TXNRD3 neighbor gene p...         3q21.3
# 13174  kelch domain-containing protein 10|PNAS-119|sc...         7q32.2
# 13722  protein turtle homolog B|MIR4697 host gene (no...          11q25
# 14018  plasminogen-like protein B|Plasminogen-like pr...         2p11.2
# 14176  neuroblastoma breakpoint family member 26|NOTC...         1p11.2
# 14640  zinc finger protein 689|short ORF-encoded hist...        16p11.2
# 14706  golgin subfamily A member 8A|88 kDa Golgi matr...          15q14
# 15013  G-protein coupled receptor-associated sorting ...         Xq22.1
# 15411  synaptotagmin-15|chr10 synaptotagmin|synaptota...       10q11.22
# 15534  probable UDP-sugar transporter protein SLC35A4...         5q31.3
# 16778  serpin-like protein HMSD|minor histocompatibil...        18q22.1
# 16845  G antigen 2A/2B|G antigen 2|cancer/testis anti...        Xp11.23
# 16846  cytosolic arginine sensor for mTORC1 subunit 2...        7q11.23
# 16982               NHS-like protein 2|TPT1-like protein         Xq13.1
# 17760  uncharacterized protein CFAP92|putative cilia ...         3q21.3
# 18165  peptidyl-prolyl cis-trans isomerase A-like 4A/...         1q21.2
# 19160  thymosin beta-15C|thymosin beta 15B-like|thymo...         Xq22.2
# 19219  zinc finger protein 578|Putative chemokine-rel...       19q13.41
# 19297  TATA-box binding protein associated factor 11 ...         5p15.1
# 19523  embryonic testis differentiation protein homol...         Xq26.3
#
#       chromosome genomic_nucleotide_accession.version  \
# 32             9                         NC_000009.12
# 134           20                         NC_000020.11
# 292           20                         NC_000020.11
# 302           11                         NC_000011.10
# 967           12                         NC_000012.12
# 1199          10                         NC_000010.11
# 1217          16                         NC_000016.10
# 1318          19                         NC_000019.10
# 1705           2                         NC_000002.12
# 1757           2                         NC_000002.12
# 2179           7                         NC_000007.14
# 2206           8                         NC_000008.11
# 2372           7                         NC_000007.14
# 2440          14                          NC_000014.9
# 2655          12                         NC_000012.12
# 2758          14                          NC_000014.9
# 2820           6                         NC_000006.12
# 2985           X                         NC_000023.11
# 4129           1                         NC_000001.11
# 4221          12                         NC_000012.12
# 4511           9                         NC_000009.12
# 5483          14                          NC_000014.9
# 5552          17                         NC_000017.11
# 6851          10                         NC_000010.11
# 7095          15                         NC_000015.10
# 7562          13                         NC_000013.11
# 8137           1                         NC_000001.11
# 8609          11                         NC_000011.10
# 8949          10                         NC_000010.11
# 9023           5                         NC_000005.10
# 10469         16                         NC_000016.10
# 10745          6                         NC_000006.12
# 11534         20                         NC_000020.11
# 11661         16                         NC_000016.10
# 11985          1                         NC_000001.11
# 12355          3                         NC_000003.12
# 13174          7                         NC_000007.14
# 13722         11                         NC_000011.10
# 14018          2                         NC_000002.12
# 14176          1                         NC_000001.11
# 14640         16                         NC_000016.10
# 14706         15                         NC_000015.10
# 15013          X                         NC_000023.11
# 15411         10                         NC_000010.11
# 15534          5                         NC_000005.10
# 16778         18                         NC_000018.10
# 16845          X                         NC_000023.11
# 16846          7                         NC_000007.14
# 16982          X                         NC_000023.11
# 17760          3                         NC_000003.12
# 18165          1                         NC_000001.11
# 19160          X                         NC_000023.11
# 19219         19                         NC_000019.10
# 19297          5                         NC_000005.10
# 19523          X                         NC_000023.11
#
#        start_position_on_the_genomic_accession  \
# 32                                  21967752.0
# 134                                  4686456.0
# 292                                 58839748.0
# 302                                 14966668.0
# 967                                 57516588.0
# 1199                                49434881.0
# 1217                                 2538021.0
# 1318                                47220824.0
# 1705                                10122568.0
# 1757                                49918503.0
# 2179                               142299011.0
# 2206                               143790925.0
# 2372                               101816007.0
# 2440                                61187468.0
# 2655                                98515573.0
# 2758                                21621904.0
# 2820                               145383353.0
# 2985                                47145221.0
# 4129                                39084167.0
# 4221                                56712427.0
# 4511                               127731524.0
# 5483                                78170373.0
# 5552                                29071122.0
# 6851                                62374369.0
# 7095                                57706714.0
# 7562                                27620743.0
# 8137                               179839976.0
# 8609                                64606174.0
# 8949                                14838306.0
# 9023                                53095679.0
# 10469                               14833721.0
# 10745                              131125627.0
# 11534                                1561385.0
# 11661                               29459913.0
# 11985                              174159520.0
# 12355                              126607050.0
# 13174                              130070534.0
# 13722                              133896438.0
# 14018                               87748087.0
# 14176                              120723945.0
# 14640                               30602558.0
# 14706                               34379068.0
# 15013                              102599348.0
# 15411                               46579128.0
# 15534                              140564828.0
# 16778                               63949301.0
# 16845                               49589496.0
# 16846                               74964705.0
# 16982                               71910845.0
# 17760                              128909873.0
# 18165                              149583848.0
# 19160                              104072887.0
# 19219                               52453553.0
# 19297                               17585162.0
# 19523                              135118955.0
#
#        end_position_on_the_genomic_accession orientation  exon_count  \
# 32                                21995324.0       minus        10.0
# 134                                4701588.0        plus         2.0
# 292                               58911192.0        plus        22.0
# 302                               14972351.0       minus         7.0
# 967                               57520517.0       minus         4.0
# 1199                              49539538.0       minus        23.0
# 1217                               2603188.0        plus        17.0
# 1318                              47232860.0       minus         8.0
# 1705                              10211010.0        plus        14.0
# 1757                              51032132.0       minus        27.0
# 2179                             142813287.0        plus         0.0
# 2206                             143815773.0       minus        37.0
# 2372                             102283958.0        plus        34.0
# 2440                              61550976.0        plus        20.0
# 2655                              98550351.0        plus        11.0
# 2758                              22552132.0        plus         0.0
# 2820                             145736023.0       minus        15.0
# 2985                              47186813.0        plus        25.0
# 4129                              39487138.0        plus       104.0
# 4221                              56725299.0       minus        11.0
# 4511                             127735294.0       minus         5.0
# 5483                              79868291.0        plus        27.0
# 5552                              29180398.0       minus        47.0
# 6851                              62480285.0        plus         7.0
# 7095                              57717557.0        plus         4.0
# 7562                              27667411.0        plus         6.0
# 8137                             179877803.0       minus        10.0
# 8609                              64723197.0       minus        25.0
# 8949                              14871741.0        plus        14.0
# 9023                              53109757.0       minus         7.0
# 10469                             14896157.0        plus        31.0
# 10745                            131283532.0        plus        23.0
# 11534                              1620009.0       minus        13.0
# 11661                             29464966.0        plus         8.0
# 11985                            174995308.0        plus        42.0
# 12355                            126655124.0       minus        16.0
# 13174                            130135705.0        plus        12.0
# 13722                            133956968.0       minus        20.0
# 14018                             87759476.0        plus         4.0
# 14176                            120842229.0        plus        36.0
# 14640                             30610775.0       minus         5.0
# 14706                             34437808.0       minus        25.0
# 15013                            102908064.0        plus        32.0
# 15411                             46597108.0        plus         9.0
# 15534                            140569100.0        plus         3.0
# 16778                             63969648.0        plus         6.0
# 16845                             49596824.0        plus         5.0
# 16846                             75031528.0        plus         9.0
# 16982                             72153286.0        plus        11.0
# 17760                            129026748.0       minus        23.0
# 18165                            149584607.0        plus         1.0
# 19160                            104076236.0       minus         3.0
# 19219                             52516882.0        plus        11.0
# 19297                             17585758.0       minus         1.0
# 19523                            135120526.0       minus         3.0
#
#                 OMIM                    swissprot_id
# 32            600160                  P42771, Q8N726
# 134           176640                  F7VJQ1, P04156
# 292           139320  O95467, P63092, P84996, Q5JWF2
# 302           114130                  P01258, P06881
# 967           126337                  P0DPQ6, P35638
# 1199          609413                  P0DP91, Q03468
# 1217          605213                  O15530, Q6A1A2
# 1318          605854                  Q96PG8, Q9BXH1
# 1705          180390                  P31350, Q96LS8
# 1757          600565                  P58400, Q9ULB1
# 2179             NaN                  P0DSE2, P0DTU4
# 2206          607733                  C0HLS1, Q14160
# 2372          116896                  P39880, Q13948
# 2440          605437                  C0HM02, P24723
# 2655          188380                  P42166, P42167
# 2758             NaN                  P0DSE1, P0DTU3
# 2820          607566                  B3EWF7, O95278
# 2985          300080                  P0DW28, P98175
# 4129          608271                  O94854, Q9UPN3
# 4221          601234                  E9PAV3, Q13765
# 4511          608052                  Q5JU69, Q8N2E6
# 5483          600567                  Q9HDB5, Q9Y4C0
# 5552   609517,610067                  O95411, Q92614
# 6851          607818                  Q70YC4, Q70YC5
# 7095          606485                  P0CAP2, Q6EEV4
# 7562          613715                  P0DPB5, P0DPB6
# 8137          614513                  Q8NFQ8, Q9H496
# 8609          600566                  P58401, Q9P2S2
# 8949          610369              A0A1W2PQ72, Q0VDF9
# 9023          603708                  O96007, O96033
# 10469         609157                  P69849, Q15155
# 10745         604693                  O43687, Q9P0M2
# 11534         603889                  O00241, Q5TFQ8
# 11661         615819                  P0DMM9, P0DMN0
# 11985         609238                  B7ZAP0, Q5R372
# 12355         606235                  Q6F5E7, Q86VQ6
# 13174         615152                  Q6PID8, Q9BZS9
# 13722         613773                  Q6AWC8, Q9UPX0
# 14018            NaN                  Q02325, Q15195
# 14176            NaN              A0A096LNW5, B4DH59
# 14640         618033                  C0HLU2, Q96CS4
# 14706         616180                  A7E2F4, A8MQT2
# 15013            NaN                  Q6PI77, Q96D09
# 15411         608081                  Q9BQS2, X6R8R1
# 15534         620297                  L0R6Q1, Q96G79
# 16778         612086                  A8MTL9, P0C7T4
# 16845         300720                  Q13066, Q6NT46
# 16846         617033                  A6NHX0, Q8N976
# 16982         301093                  Q56UQ5, Q5HYW2
# 17760            NaN                  Q6ZUG5, Q9ULG3
# 18165            NaN              A0A0B4J2A2, Q9Y536
# 19160            NaN                  P0CG35, P0DX04
# 19219            NaN                  Q1T7F1, Q96N58
# 19297            NaN              A0A1W2PP81, P0DW12
# 19523            NaN                  P0DPP9, Q3ZM63

# %%
df_all.at[32, 'swissprot_id'] = "P42771"
df_all.at[134, 'swissprot_id'] = "P04156"
df_all.at[292, 'swissprot_id'] = "Q5JWF2"
df_all.at[302, 'swissprot_id'] = "P06881"
df_all.at[967, 'swissprot_id'] = "P35638"
df_all.at[1199, 'swissprot_id'] = "Q03468"
df_all.at[1217, 'swissprot_id'] = "O15530"
df_all.at[1318, 'swissprot_id'] = "Q9BXH1"
df_all.at[1705, 'swissprot_id'] = "P31350"
df_all.at[1757, 'swissprot_id'] = "Q9ULB1"
df_all.at[2179, 'swissprot_id'] = "P0DTU4"
df_all.at[2206, 'swissprot_id'] = "Q14160"
df_all.at[2372, 'swissprot_id'] = "P39880"
df_all.at[2440, 'swissprot_id'] = "P24723"
df_all.at[2655, 'swissprot_id'] = "P42166"
df_all.at[2758, 'swissprot_id'] = "P0DSE1"
df_all.at[2820, 'swissprot_id'] = "O95278"
df_all.at[2985, 'swissprot_id'] = "P98175"
df_all.at[4129, 'swissprot_id'] = "Q9UPN3"
df_all.at[4221, 'swissprot_id'] = "Q13765"
df_all.at[4511, 'swissprot_id'] = "Q8N2E6"
df_all.at[5483, 'swissprot_id'] = "Q9Y4C0"
df_all.at[5552, 'swissprot_id'] = "Q92614"
df_all.at[6851, 'swissprot_id'] = "Q70YC5"
df_all.at[7095, 'swissprot_id'] = "P0CAP2"
df_all.at[7562, 'swissprot_id'] = "P0DPB6"
df_all.at[8137, 'swissprot_id'] = "Q8NFQ8"
df_all.at[8609, 'swissprot_id'] = "Q9P2S2"
df_all.at[8949, 'swissprot_id'] = "Q0VDF9"
df_all.at[9023, 'swissprot_id'] = "O96007"
df_all.at[10469, 'swissprot_id'] = "Q15155"
df_all.at[10745, 'swissprot_id'] = "O43687"
df_all.at[11534, 'swissprot_id'] = "O00241"
df_all.at[11661, 'swissprot_id'] = "P0DMN0"
df_all.at[11985, 'swissprot_id'] = "Q5R372"
df_all.at[12355, 'swissprot_id'] = "Q86VQ6"
df_all.at[13174, 'swissprot_id'] = "Q6PID8"
df_all.at[13722, 'swissprot_id'] = "Q9UPX0"
df_all.at[14018, 'swissprot_id'] = "Q15195"
df_all.at[14176, 'swissprot_id'] = "A0A096LNW5"
df_all.at[14640, 'swissprot_id'] = "Q96CS4"
df_all.at[14706, 'swissprot_id'] = "A8MQT2"
df_all.at[15013, 'swissprot_id'] = "Q6PI77"
df_all.at[15411, 'swissprot_id'] = "Q9BQS2"
df_all.at[15534, 'swissprot_id'] = "Q96G79"
df_all.at[16778, 'swissprot_id'] = "P0C7T4"
df_all.at[16845, 'swissprot_id'] = "Q13066"
df_all.at[16846, 'swissprot_id'] = "A6NHX0"
df_all.at[16982, 'swissprot_id'] = "Q5HYW2"
df_all.at[17760, 'swissprot_id'] = "Q9ULG3"
df_all.at[18165, 'swissprot_id'] = "Q9Y536"
df_all.at[19160, 'swissprot_id'] = "P0CG35"
df_all.at[19219, 'swissprot_id'] = "Q96N58"
df_all.at[19297, 'swissprot_id'] = "P0DW12"
df_all.at[19523, 'swissprot_id'] = "Q3ZM63"

# %%
# save into a file
df_all.to_csv(join(path_prefix, "maf_analysis_all_repair/df_all_w_most_swissprot_ids_unique.txt"), sep="\t")

# %% [markdown]
# ## 3) UniProt Data Acquisition

# %% [markdown]
# #### a) Install UniProt API

# %%
# !pip install bioservices
from bioservices import UniProt
from io import StringIO
# Out:
# Requirement already satisfied: bioservices in /usr/local/lib/python3.10/dist-packages (1.11.2)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.10/dist-packages (from bioservices) (1.4.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bioservices) (4.12.3)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from bioservices) (6.8.2)
# Requirement already satisfied: easydev>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from bioservices) (0.13.1)
# Requirement already satisfied: grequests in /usr/local/lib/python3.10/dist-packages (from bioservices) (0.7.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bioservices) (3.7.1)
# Requirement already satisfied: pandas>=0.21.1 in /usr/local/lib/python3.10/dist-packages (from bioservices) (1.5.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bioservices) (2.31.0)
# Requirement already satisfied: requests-cache in /usr/local/lib/python3.10/dist-packages (from bioservices) (1.2.0)
# Requirement already satisfied: suds-community>=0.7 in /usr/local/lib/python3.10/dist-packages (from bioservices) (1.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from bioservices) (4.9.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from bioservices) (4.66.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from bioservices) (1.14.1)
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.10/dist-packages (from bioservices) (0.13.0)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from easydev>=0.12.0->bioservices) (0.4.6)
# Requirement already satisfied: line-profiler<5.0.0,>=4.1.2 in /usr/local/lib/python3.10/dist-packages (from easydev>=0.12.0->bioservices) (4.1.2)
# Requirement already satisfied: pexpect<5.0.0,>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from easydev>=0.12.0->bioservices) (4.9.0)
# Requirement already satisfied: platformdirs<5.0.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from easydev>=0.12.0->bioservices) (4.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.21.1->bioservices) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.21.1->bioservices) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.21.1->bioservices) (1.25.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bioservices) (2.5)
# Requirement already satisfied: gevent in /usr/local/lib/python3.10/dist-packages (from grequests->bioservices) (24.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bioservices) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bioservices) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bioservices) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bioservices) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bioservices) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bioservices) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bioservices) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bioservices) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bioservices) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bioservices) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bioservices) (2024.2.2)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache->bioservices) (23.1.0)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache->bioservices) (23.2.3)
# Requirement already satisfied: url-normalize>=1.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache->bioservices) (1.4.3)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache->bioservices) (1.2.0)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache->bioservices) (4.10.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect<5.0.0,>=4.9.0->easydev>=0.12.0->bioservices) (0.7.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.21.1->bioservices) (1.16.0)
# Requirement already satisfied: zope.event in /usr/local/lib/python3.10/dist-packages (from gevent->grequests->bioservices) (5.0)
# Requirement already satisfied: zope.interface in /usr/local/lib/python3.10/dist-packages (from gevent->grequests->bioservices) (6.2)
# Requirement already satisfied: greenlet>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from gevent->grequests->bioservices) (3.0.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from zope.event->gevent->grequests->bioservices) (67.7.2)

# %% [markdown]
# #### b) Get protein length of all genes

# %%
# initialise uniprot
u = UniProt()

for index, row in df_all[df_all["swissprot_id"] != "NotFound"].iterrows():
  # get uniprot id
  uniprot_id = row['swissprot_id']

  # get gene result
  result = u.search(uniprot_id)
  result_df = pd.read_csv(StringIO(result), sep='\t')

  # check if there is only one entry
  if result_df.shape[0] != 1:
    result_df = result_df[result_df['Reviewed']=="reviewed"]

  # write the length into df_all
  df_all.loc[index, "protein_length"] = int(result_df.iloc[0]["Length"])

df_all
# Out:
#        tax_id      Org_name     GeneID  CurrentID Status        Symbol  \
# 0        9606  Homo sapiens       7157          0   live          TP53
# 1        9606  Homo sapiens       1956          0   live          EGFR
# 2        9606  Homo sapiens        348          0   live          APOE
# 3        9606  Homo sapiens       7124          0   live           TNF
# 4        9606  Homo sapiens       7422          0   live         VEGFA
# ...       ...           ...        ...        ...    ...           ...
# 20622    9606  Homo sapiens  100996709          0   live  LOC100996709
# 20623    9606  Homo sapiens  100996701          0   live  LOC100996701
# 20624    9606  Homo sapiens  100996696          0   live  LOC100996696
# 20625    9606  Homo sapiens  100507221          0   live  LOC100507221
# 20626    9606  Homo sapiens  100129098          0   live  LOC100129098
#
#                                             Aliases  \
# 0                     BCC7, BMFS5, LFS1, P53, TRP53
# 1      ERBB, ERBB1, ERRP, HER1, NISBD2, PIG61, mENA
# 2                    AD2, APO-E, ApoE4, LDLCQ5, LPG
# 3              DIF-alpha, TNFA, TNFSF2, TNLG1F, TNF
# 4                          L-VEGF, MVCD1, VEGF, VPF
# ...                                             ...
# 20622                                           NaN
# 20623                                           NaN
# 20624                                           NaN
# 20625                                           NaN
# 20626                                           NaN
#
#                                    description  \
# 0                            tumor protein p53
# 1             epidermal growth factor receptor
# 2                             apolipoprotein E
# 3                        tumor necrosis factor
# 4         vascular endothelial growth factor A
# ...                                        ...
# 20622  ADP-ribosylation factor-like protein 17
# 20623             uncharacterized LOC100996701
# 20624     polyadenylate-binding protein 4-like
# 20625             uncharacterized LOC100507221
# 20626             uncharacterized LOC100129098
#
#                                       other_designations map_location  \
# 0      cellular tumor antigen p53|antigen NY-CO-13|mu...      17p13.1
# 1      epidermal growth factor receptor|EGFR vIII|avi...       7p11.2
# 2                     apolipoprotein E|apolipoprotein E3     19q13.32
# 3      tumor necrosis factor|APC1 protein|TNF, macrop...      6p21.33
# 4      vascular endothelial growth factor A, long for...       6p21.1
# ...                                                  ...          ...
# 20622            ADP-ribosylation factor-like protein 17          NaN
# 20623               uncharacterized protein LOC100996701     12q24.33
# 20624               polyadenylate-binding protein 4-like      12q14.1
# 20625               uncharacterized protein LOC100507221      16p11.2
# 20626                 translation initiation factor IF-2      8q11.23
#
#       chromosome genomic_nucleotide_accession.version  \
# 0             17                         NC_000017.11
# 1              7                         NC_000007.14
# 2             19                         NC_000019.10
# 3              6                         NC_000006.12
# 4              6                         NC_000006.12
# ...          ...                                  ...
# 20622         17                                  NaN
# 20623         12                         NC_000012.12
# 20624         12                         NC_000012.12
# 20625         16                         NC_000016.10
# 20626          8                         NC_000008.11
#
#        start_position_on_the_genomic_accession  \
# 0                                    7668421.0
# 1                                   55019017.0
# 2                                   44905796.0
# 3                                   31575565.0
# 4                                   43770211.0
# ...                                        ...
# 20622                                      NaN
# 20623                              131663774.0
# 20624                               59812094.0
# 20625                               32264029.0
# 20626                               54465594.0
#
#        end_position_on_the_genomic_accession orientation  exon_count    OMIM  \
# 0                                  7687490.0       minus        13.0  191170
# 1                                 55211628.0        plus        32.0  131550
# 2                                 44909393.0        plus         6.0  107741
# 3                                 31578336.0        plus         4.0  191160
# 4                                 43786487.0        plus         9.0  192240
# ...                                      ...         ...         ...     ...
# 20622                                    NaN         NaN         NaN     NaN
# 20623                            131664548.0       minus         1.0     NaN
# 20624                             59812618.0        plus         1.0     NaN
# 20625                             32280475.0       minus         5.0     NaN
# 20626                             54470426.0       minus         2.0     NaN
#
#       swissprot_id  protein_length
# 0           P04637           393.0
# 1           P00533          1210.0
# 2           P02649           317.0
# 3           P01375           233.0
# 4           P15692           395.0
# ...            ...             ...
# 20622     NotFound             NaN
# 20623     NotFound             NaN
# 20624     NotFound             NaN
# 20625     NotFound             NaN
# 20626     NotFound             NaN
#
# [20627 rows x 19 columns]

# %%
# save into a file
df_all.to_csv(join(path_prefix, "maf_analysis_all_repair/df_all_most_23032024.txt"), sep="\t")
